# %%
# !pip install wikipedia-api
import wikipediaapi
import sys
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#   Created wheel for wikipedia-api: filename=Wikipedia_API-0.5.4-py3-none-any.whl size=13476 sha256=f7c5667afdb41c9c6c7e21d7a2fde48521ec293c34902438defd83e591807ddf
#   Stored in directory: /root/.cache/pip/wheels/d3/24/56/58ba93cf78be162451144e7a9889603f437976ef1ae7013d04
# Successfully built wikipedia-api
# ...

# %%
class FPTree:
    class Node:
        def __init__(self, item, frequency, parent):
            self.item = item
            self.freq = frequency
            self.nodeLink = None
            self.parent = parent
            self.children = {}

        def _counter(self, frequency):
            self.freq += frequency

        def display(self):
            print(f'item: {self.item}, freq: {self.freq}', end='')
            if len(self.children) > 0:
                print(",[", end='')
            for c in self.children.values():
                print("[", end='')
                c.display()
                if len(c.children) == 0:
                    print("]", end='')
            print("]", end='')

    def getData(self, wikipages):
        self.data = []
        for page in wikipages:
            p_wiki = wiki_wiki.page(page)
            self.data.append(p_wiki.text.split(sep=' '))
        self.Dict = {}
        for i in self.data:
            self.Dict[frozenset(i)] = 1
        return self.Dict

    def makeTree(self, data, freqThreshold=2):
        HeaderTable = {}
        for page in data:
            for item in page:
                HeaderTable[item] = HeaderTable.get(item, 0) + data[page]
        for i in list(HeaderTable):
            if HeaderTable[i] < freqThreshold:
                del (HeaderTable[i])

        freqItemSet = set(HeaderTable.keys())

        if len(freqItemSet) == 0:
            return None, None

        for i in HeaderTable:
            HeaderTable[i] = [HeaderTable[i], None]

        FPTree = self.Node('root', 1, None)
        for itemset, freq in data.items():
            frequent_transaction = {}
            for item in itemset:
                if item in freqItemSet:
                    frequent_transaction[item] = HeaderTable[item][0]
            if len(frequent_transaction) > 0:
                ordered_itemset = [x[0] for x in sorted(frequent_transaction.items(), key=lambda y: y[1], reverse=True)]
                self._update(ordered_itemset, FPTree, HeaderTable, freq)
        return FPTree, HeaderTable

    def _update(self, itemset, FPTree, HeaderTable, freq):
        if itemset[0] in FPTree.children:
            FPTree.children[itemset[0]]._counter(freq)
        else:
            FPTree.children[itemset[0]] = self.Node(itemset[0], freq, FPTree)

            if HeaderTable[itemset[0]][1] == None:
                HeaderTable[itemset[0]][1] = FPTree.children[itemset[0]]
            else:
                self._updateNode(HeaderTable[itemset[0]][1], FPTree.children[itemset[0]])

        if len(itemset) > 1:
            self._update(itemset[1::], FPTree.children[itemset[0]], HeaderTable, freq)

    def _updateNode(self, xNode, yNode):
        while (xNode.nodeLink != None):
            xNode = xNode.nodeLink

        xNode.nodeLink = yNode

    def _uptransveral(self, leaf_Node, path):
        if leaf_Node.parent != None:
            path.append(leaf_Node.item)
            self._uptransveral(leaf_Node.parent, path)

    def _findPath(self, basePat, treeNode):
        conditionalPatternBase = {}

        while treeNode != None:
            path = []
            self._uptransveral(treeNode, path)
            if len(path) > 1:
                conditionalPatternBase[frozenset(path[1:])] = treeNode.freq
            treeNode = treeNode.nodeLink

        return conditionalPatternBase

    def mine(self, FPTree, HeaderTable, threshold, prefix, frequent_itemset):
        basePatList = [x[0] for x in sorted(HeaderTable.items(), key=lambda y: y[1][0])]
        for basePat in basePatList:
            frequentset = prefix.copy()
            frequentset.add(basePat)
            frequent_itemset.append(frequentset)
            conditionalPatternBases = self._findPath(basePat, HeaderTable[basePat][1])
            conditionalFPTree, conditionalHeader = self.makeTree(conditionalPatternBases, threshold)
            if conditionalHeader != None:
                self.mine(conditionalFPTree, conditionalHeader, threshold, frequentset, frequent_itemset)

# %%
DSA = ['Deep reinforcement learning',
 'Dehaene–Changeux model',
 'Diffusion map',
 'Diffusion model',
 'Dominance-based rough set approach',
 'Dynamic time warping',
 'Cardinal tree',
 'Collection (abstract data type)',
 'Container (abstract data type)',
 'Linked data structure',
 'List (abstract data type)',
 'Set (abstract data type)',
 'Stack (abstract data type)',
 'Tree (data structure)',
 'Peek (data type operation)',
 'Pile (abstract data type)',
 'Priority queue',
 'Double-ended priority queue',
 'Double-ended queue',
 'Magic state distillation',
 'Plotting algorithms for the Mandelbrot set',
 'Manhattan address algorithm',
 'The Master Algorithm',
 'Maze generation algorithm',
 'Maze-solving algorithm',
 'Medical algorithm',
 "Miller's recurrence algorithm",
 'Multiplicative weight update method',
 'Sardinas–Patterson algorithm',
 'Sequential algorithm',
 'Serial algorithm',
 'Shapiro Senapathy algorithm',
 'Shuffling algorithm',
 'Sieve of Eratosthenes',
 'Sieve of Pritchard',
 'Simulation algorithms for atomic DEVS',
 'Simulation algorithms for coupled DEVS',
 'Snap rounding',
 'Spreading activation',
 'Super-recursive algorithm',
 'Adaptive algorithm',
 'Algorism',
 'The Algorithm Auction',
 'Algorithm characterizations',
 'Algorithm engineering',
 'Algorithmic game theory',
 'Algorithmic logic',
 'Algorithmic management',
 'Algorithmic mechanism design',
 'Algorithmic paradigm',
 'Algorithmic Puzzles',
 'Algorithmic transparency',
 'Algorithms and Combinatorics',
 'Algorithms of Oppression',
 'Automate This',
 'AVT Statistical filtering algorithm',
 'Recursion (computer science)',
 'Recursive acronym',
 'Recursive definition',
 'Recursive function',
 'Recursive islands and lakes',
 'Recursive language',
 'Reentrancy (computing)',
 'A* search algorithm',
 'All nearest smaller values',
 'Alpha–beta pruning',
 'Amplitude amplification',
 'Any-angle path planning',
 'Anytime A*',
 'Anytime algorithm',
 'Search game',
 'Search tree',
 'Search-based software engineering',
 'Siamese method',
 'Similarity search',
 'SMA*',
 'Spiral hashing',
 'Spreading activation',
 'SSS*',
 'Stack search',
 'State space search',
 'Sudoku solving algorithms',
 'Late move reductions',
 'Lexicographic breadth-first search',
 'Lifelong Planning A*',
 'Linear hashing',
 'Linear probing',
 'Linear search',
 'Linear-quadratic regulator rapidly-exploring random tree',
 'Locality-sensitive hashing',
 'Look-ahead (backtracking)',
 'Genetic algorithm',
 'Geometric hashing',
 'Gestalt pattern matching',
 "God's algorithm",
 'Golden-section search',
 'Graphplan',
 "Grover's algorithm",
 'Nearest neighbor search',
 'NewsRx']

# %%
if __name__ == '__main__':
    sys.setrecursionlimit(60000)

    wiki_wiki = wikipediaapi.Wikipedia(language='en', extract_format=wikipediaapi.ExtractFormat.WIKI)

    wiki = ["Genetic algorithm", "A* search algorithm", "Search tree", "Recursion (computer science)", "Linear search"]

    test = FPTree()

    # data = test.get_data(DSA) ## ran out of memory with DSA list because it's too large.

    data = test.getData(wiki)

    FPtree, HeaderTable = test.makeTree(data)

    frequent_itemset = []

    test.mine(FPtree, HeaderTable, 5, set([]), frequent_itemset)

    print("All frequent itemsets:")
    print(frequent_itemset)
    print(f"FPtree Children {FPtree.children}")
    print(f"Header Table {HeaderTable}")
    print(test.Dict)
# Out:
# All frequent itemsets:
# ...

# %%
FPtree.display() # Depth First Search (DFS)
# Out:
# item: root, freq: 1,[[item: time, freq: 2,[[item: computer, freq: 2,[[item: which, freq: 2,[[item: number, freq: 2,[[item: search, freq: 2,[[item: its, freq: 2,[[item: be, freq: 2,[[item: most, freq: 2,[[item: large, freq: 2,[[item: than, freq: 2,[[item: some, freq: 2,[[item: other, freq: 2,[[item: an, freq: 2,[[item: it, freq: 2,[[item: as, freq: 2,[[item: where, freq: 2,[[item: can, freq: 2,[[item: is, freq: 2,[[item: in, freq: 2,[[item: if, freq: 2,[[item: not, freq: 2,[[item: a, freq: 2,[[item: to, freq: 2,[[item: The, freq: 2,[[item: are, freq: 2,[[item: single, freq: 2,[[item: at, freq: 2,[[item: have, freq: 2,[[item: often, freq: 2,[[item: algorithm, freq: 2,[[item: algorithms, freq: 2,[[item: that, freq: 2,[[item: will, freq: 2,[[item: all, freq: 2,[[item: but, freq: 2,[[item: from, freq: 2,[[item: each, freq: 2,[[item: In, freq: 2,[[item: then, freq: 2,[[item: of, freq: 2,[[item: equal, freq: 2,[[item: two, freq: 2,[[item: for, freq: 2,[[item: same, freq: 2,[[item: has, freq
# ...

# %%
print(FPtree.children)
print(FPtree.children["time"].children)
print(FPtree.children["time"].children['computer'].children)
print(FPtree.children["time"].children['computer'].children["which"].children)
print(FPtree.children["time"].children['computer'].children["which"].children["number"].children)
# Out:
# {'time': <__main__.FPTree.Node object at 0x7fcf5f8a1550>, 'other': <__main__.FPTree.Node object at 0x7fcf5f7a0590>, 'then': <__main__.FPTree.Node object at 0x7fcf5f7c9090>}
# {'computer': <__main__.FPTree.Node object at 0x7fcf5f8a13d0>}
# {'which': <__main__.FPTree.Node object at 0x7fcf5f8a1090>}
# {'number': <__main__.FPTree.Node object at 0x7fcf5f8a10d0>}
# {'search': <__main__.FPTree.Node object at 0x7fcf5f8a12d0>}
